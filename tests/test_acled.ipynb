# %%
from ingest.acled_client import AcledClient
from utils.dates import start_date, end_date
from utils.constants import COUNTRY

# %%
acled = AcledClient()
# Out:
# INFO:ACLED ingest:Access token correctly retrieved.

# %%
df = acled.get_data(country=COUNTRY, start_date=start_date, end_date=end_date)
# Out:
# INFO:ACLED ingest:Reading data from data/acled/acled_data_sudan.csv.

# %%
df = acled.get_data(country=COUNTRY, start_date=start_date, end_date=end_date)
# Out:
# INFO:ACLED ingest:Reading data from data/acled/acled_data_sudan.csv.

# %%
df = acled.get_data(country=COUNTRY, start_date=start_date, end_date=end_date)
# Out:
# INFO:ACLED ingest:Reading data from data/acled/acled_data_sudan.csv.

# %%
from processing.acled_events_processing import get_clean_data

# %%
test = get_clean_data()
# Out:
# INFO:ACLED ingest:Access token correctly retrieved.
# INFO:ACLED ingest:Reading data from data/acled/acled_data_sudan.csv.
# INFO:Events processing:Data grouped by event_type
# INFO:Events processing:Escalation target set at 0.5 standard deviations above the mean.
