# %%
from ingest.acled_client import AcledClient
from utils.dates import start_date, end_date
from utils.name_mapping import COUNTRIES

# %%
acled = AcledClient()
# Out:
# INFO:ACLED ingest:Access token correctly retrieved.

# %%
df = acled.get_data(countries=COUNTRIES, start_date=start_date, end_date=end_date, download=False)
# Out:
# WARNING:ACLED ingest:No saved data found for sudan. Set download to True.

# %%
df = acled.get_data(countries=COUNTRIES, start_date=start_date, end_date=end_date, download=True)
# Out:
# INFO:ACLED ingest:Requesting data...
# INFO:ACLED ingest:Requesting data...
# INFO:ACLED ingest:Requesting data...
# INFO:ACLED ingest:Requesting data...
# INFO:ACLED ingest:Requesting data...
# INFO:ACLED ingest:All data successfully fetched.
# INFO:ACLED ingest:Data saved to data/acled/acled_data_sudan.csv.

# %%
df = acled.get_data(countries=COUNTRIES, start_date=start_date, end_date=end_date, download=False)
# Out:
# INFO:ACLED ingest:Reading data from data/acled/acled_data_sudan.csv.
